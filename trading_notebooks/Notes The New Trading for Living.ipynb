# %% [markdown]
# <center>
#     <h1>The New Trading for Living</h1>
#     Dr. Alexander Elder
# </center>

# %% [markdown]
# <h3>Introduction</h3>

# %% [markdown]
# * Trading is a __minus-sum game__. Winners receive less than what losers lose because the industry drains money from the market.
# * __Commissions__ and __slippage__ are to traders what death and taxes are to all of us.
#
# >1. Look for a broker with the __cheapest commissions__ and watch him like a hawk.
# 2. Design a trading system that gives signals relatively infrequently and allows you to enter markets during
# __quiet times__.
# 3. Use __limit orders__ almost exclusively—except when placing stops.
# 4. Be careful on what __tools__ you spend money: there are no magic solutions. Success cannot be bought, only earned.

# %% [markdown]
# <h2>PART I : Individual Psychology</h2>

# %% [markdown]
# > _About Trader_
# >* People trade for many reasons—some rational and __many irrational__.
# >* Many traders are loners who abandon the certainties of the routine and take a leap into the unknown.
#
# > _Winners_
# >* A successful trader is a __realist__. A professional trader cannot afford illusions.
# >* There are no cheat sheets in the markets—you can see the truth in your __trade diaries__ and
# __equity curves__.
#
# > _Losers_
# >* Losers who suffer from the __“brain myth”__ will tell you, “I lost because I didn’t know trading secrets.”
# >* Losers don’t realize that trading is __intellectually fairly simple__. It is nowhere near as demanding as taking out an appendix, building a bridge, or trying a case in court.
# >* Many losers think that they would trade successfully if they had a bigger account (__The Undercapitalization Myth__).
# >* A loser is not undercapitalized—__his mind is underdeveloped__.
# >* A loser’s true problem is not account size but __overtrading__ and __sloppy money management__.

# %% [markdown]
# <h4>Three essential components of trading:</h4>
#
# 1. __Sound Psychology__,
# 2. __Logical Trading System__, and
# 3. __Effective Risk Management Plan__
#
# >These are like three legs of a stool—remove one and the stool will fall. It is a typical
# beginner mistake to focus exclusively on indicators and trading systems.
# You have to analyze your feelings as you trade to make sure that your decisions are sound.
# Your trades must be based on clearly defined rules. You have to structure your money manage-
# ment so that no string of losses can kick you out of the game

# %% [markdown]
# <h4>Trading Lessons from AA</h4>
#
# I’ve become convinced that traders can stop losing money if they apply the key principles of Alcoholics Anonymous to their trading. See https://www.aa.org/twelve-steps-twelve-traditions
#
# __*Analogy*__ :
# Alcoholics __deny__ their problems while their lives are falling apart. As long as an
# alcoholic believes that he can __“control his drinking”__, he is headed downhill. _Nothing
# will ever change, even if he gets a new job, a new wife, and a new landlord_.
#
# >There is a stark parallel between an alcoholic and a trader whose account is being demol-
# ished by losses. As he keeps changing his trading tactics, he acts like an alcoholic who tries to
# solve his problem by switching from hard liquor to beer. A loser denies that he’s lost control over
# his trading life.
#
# _You may have seen bumper stickers that say, __“One day at a time”__ or “Easy does it.” Those
# are AA slogans, and people who drive those cars are probably recovering alcoholics._
#
# As traders, we always take businessman’s risks, but we may never take a loss greater than this
# predetermined risk.

# %% [markdown]
# <h2>PART II : Classical Chart Analysis</h2>

# %% [markdown]
# <h3>17. Charting</h3>
#
# _Chart_
#
# * Classical charting, on the other hand, is quite __subjective__, and invites wishful thinking and self-deception. In my own trading, I use only a small number of chart patterns that are objective enough to trust.
# * After having looked at hundreds of thousands of charts, I’ve concluded that __the market doesn’t know diagonals__.
# * Chart patterns reflect __the sum of buying and selling__, greed and fear among investors and traders.

# %% [markdown]
# **<center>“Each price is a momentary consensus of value of all market
# participants expressed in action.”</center>**

# %% [markdown]
# _Opening Price_
# * The __opening price__ of a daily bar tends to reflect the amateurs’ opinion of value.
# * Traders who researched the relationship between opening and closing prices found that opening prices most often occur near the high or the low of the daily bar

# %% [markdown]
# _Closing Price_
# * The __closing prices__ of daily and weekly bars tend to reflect the actions of professional traders.
# * They watch the markets throughout the day, respond to changes, and tend to dominate the last hour of trading. Many of them take profits at that time to
# avoid carrying trades overnight.
#
# ![image.png](attachment:63da9060-9f17-4752-81c0-ebbce3d4f085.png)

# %% [markdown]
# <h4>Efficient Markets, Random Walk, Chaos Theory,
# and “Nature’s Law”</h4>
#
# * Efficient Market theory is an academic notion that nobody can outperform the market because any price at any given moment incorporates all available information.
# * Random Walk theorists claim that market prices change at random.
# * Chaos Theory has achieved prominence in the recent decades. Markets are largely chaotic, and the only time you can have an edge is during orderly periods.
# * Nature’s Law is the rallying cry of a clutch of mystics who claim there is a perfect order in the markets

# %% [markdown]
# <h3>18. Support and Resistance</h3>
#
# * __Support__ (__Resistance__) is a price level where buying (selling) is strong enough to interrupt or reverse a downtrend (uptrend). Support (resistance) is represented on a chart by a horizontal line connecting __two or more bottoms__ .
# *  Support and resistance areas often __switch roles__.
# * The strength of these barriers __increases__ each time prices touch them and bounce away.
# * Beware of __false breakouts__ from support and resistance. Amateurs tend to __follow breakouts__, while professionals tend to __fade (trade against) them__.

# %% [markdown]
# _<center>Support and resistance exist because people have memories.</center>_
# _<center>Support and resistance exist because masses of traders feel pain and regret.</center>_

# %% [markdown]
# <h4>Trading Rules</h4>
# <ol>
#     <li>Whenever the trend you’re riding approaches support or resistance, tighten your protective stop.</li>
#     <li>Support and resistance are more important on long-term charts than on short- term charts.</li>
#     <li>Support and resistance levels point to trading opportunities</li>
# </ol>

# %% [markdown]
# _<center>**On Placing Stops** : Experienced traders tend to avoid placing them at round numbers</center>_

# %% [markdown]
# <h4>True and False Breakouts</h4>
#
# * Markets spend more time in trading ranges than in trends. Most breakouts from trading ranges are false breakouts.
# * Professionals expect prices to fluctuate most of the time, without going anywhere far.
# * The best time to buy an upside breakout on a daily chart is when your analysis of the weekly chart suggests that a new uptrend is developing.
# *  True breakouts are confirmed by heavy volume, while false breakouts tend to have light volume

# %% [markdown]
# <h3>19. Trends and Trading Ranges<h5>p.60</h5></h3>
#
# * In a trading range, most rallies stop at about the same high level, and declines peter out at about the same low level.
#
# * __Trends__ and __trading ranges__ call for different tactics.
# <ol>
#     <li>When you go long in an uptrend or sell short in a downtrend, you have to give that trend the benefit of
# the doubt and use a wider stop, so as not to be shaken out easily. You have to <b>follow strength during trends</b>—buy in uptrends and short in downtrends.</li>
#     <li>In a trading range, on the other hand, you have to use tight stops, be nimble and close out positions at
#         the slightest sign of a reversal. You aim to <b>buy weakness</b> and <b>sell strength</b></li>
#
# </ol>

# %% [markdown]
# <h4>The Hard Right Edge</h4>
#
# * Trends and ranges are easy to see in the middle of a chart, but as you get close to its right edge, the picture becomes increasingly foggy.
# * Many chart patterns and indicator signals contradict one another at the right edge of the chart.
#
# >Most people feel very uncomfortable dealing with uncertainty. When their trade
# doesn’t go the way their analysis suggested, they hang onto losing positions, waiting
# for the market to turn and make them whole. Trying to be right is an unaffordable
# luxury in the markets. __Professional traders get out of losing trades fast__. When the
# market deviates from your analysis, you have to cut losses without fuss

# %% [markdown]
# <h4>Methods and Techniques</h4>
#
# Keep in mind that there is no single magic method to clearly and reliably identify all
# trends and trading ranges. It pays to combine several analytic tools. None of them is
# perfect, but when they confirm each another, a correct message is much more likely.
# When they contradict one another, it’s better to pass up a trade.
#
# <ol>
#     <li><b>Analyze the pattern of highs and lows</b> : Uptrend, Downtrend or Trading Range</li>
#     <li><b>Plot a 20- to 30-bar exponential moving average (see Chapter 22)</b>. The direction
# of its slope identifies the trend. </li>
#     <li>When an <b>oscillator</b>, such as <b>MACD-Histogram (see Chapter 23)</b> rises to a new peak, it identifies a powerful trend and suggests that the latest market top is likely to be retested or exceeded.</li>
#     <li>Several market <b>indicators</b>, such <b>the Directional system (see Chapter 24)</b>, help identify trends. The Directional system is especially good at catching early stages of new trends</li>
# </ol>

# %% [markdown]
# <h4>Trade or Wait</h4>
#
# Having identified an uptrend, you need to decide whether
# * to buy immediately or
#     * If you buy fast, you’ll get in gear with the trend, but on the minus side, your stops are likely to be farther away, increasing your risk.
# * wait for a dip
#     * If you wait for a dip, your risk will be smaller, but you’ll have four groups of competitors:
#         <ol>
#             <li>longs who want to add to their positions,</li>
#             <li>shorts who want to get out even,</li>
#             <li>traders who never bought (such as yourself),</li>
#             <li>and traders who sold too early but are eager to buy again.</li>
#         </ol> The waiting areas for pullbacks are notoriously crowded!
#
# If the market is in a trading range and you’re waiting for a breakout, you’ll have
# to decide whether
# * to buy in anticipation of a breakout,
# * during a breakout, or
# * on a pullback after a valid breakout.
#
# If you aren’t sure, consider entering in several steps:
# buy a third of the planned position in anticipation, a third on a breakout, and a third
# on a pullback.
#
# >Whatever method you use, remember to apply the key risk management rule:
# the distance from your entry to the protective stop, multiplied by position size can
# never be more than 2 percent of your account equity (see Chapter 50).
#
# Specific risk management tactics are different for trends and trading ranges.

# %% [markdown]
# <h4>Conflicting Timeframes</h4>
# The sensible course of action is this: before examining a trend on your favorite
# chart, step back to explore the charts in a timeframe one order of magnitude greater
# than your favorite. This search for a greater perspective is one of the key principles
# of the Triple Screen trading system, which we’ll discuss in a later chapter

# %% [markdown]
# <h3>20. Kangaroo Tails<h5>p.65</h5></h3>
#
#
# * Kangaroo tails, also called “fingers,” are on my short list of reliable chart formations.
# * A kangaroo tail pointing up reflects a failed attempt by the bulls to lift the market.
# * An experienced trader can recognize a kangaroo tail during its third bar, before it closes.
#
# ![image.png](attachment:ffcb97f2-48b4-4bef-9849-a57913bad37e.png)
#
#
# >For example, you may see a range that held for several days on a daily chart,
# but then on Monday the stock explodes in a very tall bar. If on Tuesday it opens near
# the base of the Monday’s bar base and refuses to rally, consider selling short before
# the market closes on Tuesday. If the market has been in a trading range for a week and
# then traces a tall bar down on Wednesday, get ready on Thursday: if prices trade in
# a narrow range near the top of the Wednesday bar, go long before the market closes
# on Thursday
#
# * __Remember that trading against the tails is a short-term tactic; on the daily charts, these signals fizzle out after a few days.__

# %% [markdown]
# <h2>PART IV : Computerized Technical Analysis</h2>

# %% [markdown]
# <h3>21. Computers in Trading<h5>p.69</h5></h3>
#
# Computerized technical analysis is more objective than classical charting. You can
# argue whether support or resistance is present—but there can be no argument about
# an indicator’s direction.
#
# As mentioned earlier in this book, most programs for technical analysis fall into
# one of three groups: __toolboxes__, __black boxes__, and __gray boxes__. Toolboxes are for seri-
# ous traders, black boxes are for people who believe in Santa Claus, and gray boxes
# are in between.

# %% [markdown]
# <h4>Toolboxes</h4>
#
# * A toolbox draws weekly, daily, and intraday charts; it splits the screen into several windowpanes for plotting prices and indicators.
# * A good toolbox allows you to compare any two markets and analyze their spreads.
# * Another feature of a good toolbox is its ability to scan stocks.
# >For example, you
# may want to find all stocks among the Nasdaq 100 whose exponential moving averages are rising, but whose prices are no more than 1% above their EMAs. Can your software scan for that? Can it add fundamental parameters to your search, such as rising earnings?
#
# * Most charts in this book are drawn using just such a service, <u>StockCharts.com</u>, because I want you to see how much you can do while spending very little.

# %% [markdown]
# <h4>Market Data</h4>
#
# * When collecting and analyzing data, don’t chase too many markets at once. Focus on quality and depth rather than quantity.Many professional traders focus on a relatively small number of stocks. They get to know them well and become familiar with their behavior patterns.
# *  Many professionals limit themselves to fewer than 100 stocks, which they review every weekend and mark their opinions in a fresh column of their spreadsheet.
# * Beginning traders should steer clear of day-trading.
# * Become a competent position or swing trader before you consider day-trading. If you compare swing trading and day-trading, it is like playing the same video game at level one or level nine.
#
# >A good place to get started is swing trading, i.e., holding positions for several
# days. Select popular stocks that have good swings on a good volume. Start out by
# following just a handful.

# %% [markdown]
# <h4>Three Major Groups of Indicators</h4>
#
# * Indicators help identify trends and reversals. They are more objective than chart patterns and provide insight into the balance of power between bulls and bears.
# * A great challenge is that various indicators may __contradict__ one another. Some of them work best in __trending markets__, others in __flat markets__. Some are good at __catching turning points__, while others are better at __riding trends__.
# * Most indicators are based on the same five pieces of data: open, high, low, close, and volume. Prices are primary; indicators are derived from them.
# * We can divide indicators into three groups:
#     <ol>
#     <li><b>Trend-following indicators</b> :  work best when markets are moving, but the quality of their signals sharply deteriorates when the markets go flat. Trend-following indicators are <b>coincident
#         or lagging indicators.</b> Ex :
#         <i>
#         <ol>
#             <li>Moving Averages</li>
#             <li>MACD Lines</li>
#             <li>The Directional System</li>
#             <li>On-Balance Volume</li>
#             <li>Accumulation/Distribution</li>
#         </ol>
#         </i>
#     </li>
#     <li><b>Oscillators</b> : catch turning points in flat markets but give premature and dangerous
#         signals when the markets begin to trend.  Oscillators are <b>leading or coincident indicators</b>
# that often turn ahead of prices. Ex :
#         <i>
#         <ol>
#             <li>MACD-Histogram</li>
#             <li>Force Index</li>
#             <li>Stochastic</li>
#             <li>Rate of Change</li>
#             <li>Momentum</li>
#             <li>The Relative Strength Index</li>
#             <li>Elder-ray</li>
#             <li>Williams %R</li>
#         </ol>
#         </i>
#     </li>
#     <li><b>Miscellaneous</b> : provide insights into mass psychology. <b>They can be leading or coincident
#         indicators</b>. Ex :
#         <i>
#         <ol>
#             <li>New High–New Low Index</li>
#             <li>The Put-Call Ratio</li>
#             <li>Bullish Consensus</li>
#             <li>Commitments of Traders</li>
#         </ol>
#         </i>
#     </li>
#     </ol>
#
# * I’ve learned long ago to enter trades only when indicator signals “grab me by the face.”
# * As you read about the signals of different indicators, remember that y<b>ou cannot base trading decisions on a single indicator</b>. We need to select several indicators we understand and trust and combine them into a trading system.

# %% [markdown]
# <h3>22. Moving Averages <h5>p.74</h5></h3>
#
# ![image.png](attachment:d4ec142d-c72b-405a-b9d5-74b37b0ebdec.png)
#
# - the MA __slope__ identifies the direction of mass inertia. When it rises, it shows that the crowd is becoming more optimistic—bullish (and vice versa).  When prices rise above a moving average, the crowd is more bullish than before (and vice versa).
#
# There are three main types of moving averages:
# - __Simple Moving Avergaes__ (SMA) : simple MAs have a fatal flaw—they change twice in response to each price.
# - __Exponential Moving Averages__ (EMA) : gives greater weight to the latest data and responds to changes faster than a simple MA.
# ![image.png](attachment:7207c04c-4a3d-48c3-b4e2-033edfc24b3e.png)
#     An EMA has two major advantages over a simple MA.
#        - First, it assigns greater weight to the last trading day.  The latest mood of the crowd is more important.
#        - Second, EMA does not drop old data the way a simple MA does. Old data slowly fades away, like a mood of the past lingering in a composite photo.
# - __Weighted Moving Averages__
#
# <h5>Choosing the Length of a Moving Average</h5>
#
# - Most traders can use an EMA between 10 and 30 days. A moving average should not be shorter than 8 days to avoid defeating its purpose as a trend-following tool.
# - Among the numbers I like are 22 because there are approximately 22 trading days in a month and 26—half of the number of trading weeks in a year.
# - Don’t change indicator parameters while looking for trades. It is better to set your parameters and live with them.

# %% [markdown]
# <h5>Trading Rules</h5>
#
# - <b>When EMA rises</b>, trade that market from the long side. <i>Buy when prices dip near the moving average</i>. Once you are long, place a protective stop below the latest minor low, and move it to the break-even point as soon as prices close higher.
# - When the EMA falls, trade that market from the short side.
# - <b>When the EMA goes flat and only wiggles a little</b>, it identifies an aimless, trendless market. Do not trade using a trend-following method.

# %% [markdown]
# <h3>27. Relative Strength Index<h5>p.99</h5></h3>
#
# - Relative Strength Index (RSI) is an __oscillator__ developed by J. Welles Wilder, Jr.
# - It measures any trading vehicle’s strength by monitoring changes in its closing prices.
# - It's a __leading__ or a __coincident__ indicator—never a laggard.
# - The pattern of RSI peaks and valleys doesn’t change in response to the width of its time window.
# -  Trading signals become more visible with shorter RSI, such as 7 or 9 days.
#
# ![image.png](attachment:21279733-e6d0-4c5c-a2b8-a2509c286aac.png)
#
# ![image.png](attachment:4230ff8b-efdf-4711-8ab9-6d5964749d88.png)
#
# >BELUM COMPLETE SUMMARYNYA,I'LL COME BACK TO THIS!

# %%
import emoji

# %% [markdown]
# <h5>Mass Psychology</h5>
#
# - Each price represents the consensus of value of all market participants at the moment of transaction.
# - The closing price reflects the most important consensus of the day because the settlement of traders’ accounts depends on it.
# - Traders pay more attention to closing prices than to any other prices of the day.
# - RSI shows whether bulls or bears are stronger at closing time—the crucial money-counting time in the market.
#
# <h5>Trading Rules</h5>
# RSI gives three types of trading signals. They are, in order of importance,
#
# - divergences,
# - chart patterns, and
# - the level of RSI

# %% [markdown]
# <ol>
#     <li><b>Bullish and Bearish Divergences</b>
#     Divergences between RSI and prices tend to occur at important tops and bottoms. They show when the trend is weak and ready to reverse.
#         <i>
#             <ol>
#                 <li>Bullish divergences give buy signals. Buy as soon as RSI turns up from its second bottom, and place a protective stop below the latest minor price low. Buy signals are especially strong if the first RSI bottom is
#     below its lower reference line and the second bottom is above that line.
#                     <center><img src="bullish-div.png"/></center>
#                 </li>
#                 <li>Bearish divergences give sell signals. Sell short as soon as
# RSI turns down from its second top, and place a protective stop above the latest
# minor high. Sell signals are especially strong if the first RSI top is above its upper
# reference line and the second top is below it.
#                 </li>
#
#
#             </ol>
#         </i>
#     </li>
#     <li><b>Charting Patterns</b> (Kurang mengertii 😅)
#     </li>
#     <li><b>RSI Levels</b>
#         <ol>
#             <li>When RSI rises above its upper reference line, it shows that bulls are strong but the
# market is overbought and entering its sell zone.</li>
#             <li>When RSI declines below its lower
# reference line, it shows that bears are strong but the market is oversold and entering
# its buy zone.</li>
#             <li>It pays to buy using overbought signals of daily RSI only when the weekly trend
# is up. It pays to sell short using sell signals of daily RSI only when the weekly trend is
# down.</li>
#         </ol>
#     </li>
# </ol>

# %% [markdown]
# <h5>Mistakes To Avoid</h5>
#
# - Typical beginner error is “shopping for indicators.”
# - It is much better to use only a small number of indicators with a strict hierarchy for their analysis, including multiple timeframes. See chapter 39 on <b>Triple Screen trading system</b>.

# %% [markdown]
# <h3>24. The Directional System<h5>p.89</h5></h3>
#
# - The Directional system is a trend-following method developed by J. Welles Wilder, Jr., in the mid-1970s and modified by several analysts.
# - It identifies trends and shows when a trend __is moving fast enough__ to make it worth following.
# -  It helps traders to profit by taking chunks out of the middle of important trends.
#
# <h5>How to Construct the Directional System</h5>
# Directional Movement is defined as the portion of today’s range that is outside of the previous day’s range.

# %% [markdown]
# <h2>PART V : Volume and Time</h2>
#
# <h3>28. Volume<h5>p.105</h5></h3>
#
# - __Volume__ consist of unit volumes. Each unit volume represent number of shares traded between two individual in a day. So (daily) volume is the total number of shares traded between same number of sellers and buyers in one day.
# -  ....

# %% [markdown]
# <h3>30. Force Index<h5>p.112</h5></h3>
#
# - Force Index is an oscillator developed by this author.
# - It combines volume with prices to discover the force of bulls or bears behind every rally or decline.
#
# $$
# \text{Force Index}_t = Vol_t \cdot (Cl_t - Cl_{t-1})
# $$
#
# - A raw Force Index can be plotted as a histogram, with a horizontal centerline at a zero level.
# - This indicator gives much better trading signals after being smoothed with a moving average
#
# <h4>Trading Rules</h4>
#
# _Short-Term Force Index_ : Since the 2-day EMA of Force Index is a sensitive tool, we can use it to fine-tune
# signals of other indicators.

# %% [markdown]
# <h2>PART VII : Trading Systems</h2>
#
# <h3>38.  System Testing, Paper Trading, and the Three Key Demands for Every Trade<h5>p.151</h5></h3>
#
# - The right process before starting with real money : __back-testing__, __forward-testing__ (trade small positions with real money) and then if the strategy seems to work, gradually increase the portion size.
# - In the end, only one kind of backtesting prepares you to
# trade—__manual testing__. It is slow, time-consuming, and cannot be automated, but
# it’s the only method that comes close to modeling real decision making. It consists
# of going through historical data one day at a time, scrupulously writing down your
# trading signals for the day ahead, and then clicking one bar forward and recording
# new signals and trades for the next day.
#
# $$
# \textit{Is TradingView provide a feature to do manual-testing ?}
# $$
#
# <h4>About Manual Testing</h4>
#
# -  Open your spreadsheet, write down your system’s rules at the top of the page, and create columns for dates, prices, and signals.
# - As you click forward, one day at a time, trends and trading ranges will slowly unfold and challenge you. At that point, you’ll be doing much more than testing a set of rules. Moving ahead one day at a time will test and improve your decision-making skills. This one-bar-at-a-time testing is vastly superior to what you can get from backtesting software.
# - If one-bar-at-a-time testing shows positive results, start trading small positions with real money.
# -  Be sure to keep good records, and if your real-money results continue positive, start increasing the size of your trades. Do it in steps, all the way up to your normal trade size.
#
# <h4>Paper Trading</h4>
#
# - Paper trading means recording your buy and sell decisions and tracking them like real trades, but with no money at risk.
# - Beginners may start out paper trading, but most people turn to it after getting beat up by the markets.
# - Psychology plays a huge role in how your trades turn out, and that’s where paper trading fails to deliver.
# - There is only one good reason to paper trade—__to test your discipline as well as your system__.
# >If you can download your data at the end of each day, do your homework, write
# down your orders for the day ahead, watch the opening and record your entries,
# then track your market each day, adjusting your profit targets and stops—if you can
# do all of this for several months in a row, recording your actions, without skipping
# a day—__then you have the discipline to trade real money__.
#
# - An impulsive person who trades for entertainment will not be able to paper trade that way because it requires real work.
#
# <h4>Elder's Strategies</h4> At the time of this writing, I have three strategies that I trade.
#
# - My favorite is a false breakout with a divergence.
# - My second choice is a pullback to value during a powerful trend—that’s the strategy of the trade shown on the screen
# - Last, I occasionally “fade an extreme”—bet on a reversal of an overstretched trend.
#
# Each of these strategies has its rules, but the key point is this—I’ll only take a trade that fits
# one of them. No chasing of random cars for this old dog!
#
# <h4>Three Key Demands for Every Trade</h4>
#
# ![image.png](attachment:5256b861-7bb0-4da1-95b0-52be69b62c1c.png)
#
# - __TRADE SETUP__ : write down the three key numbers for every trade: your __entry__,__target__, and __stop__. Before entering the market you need to decide how much you’ll pay, how much you’ll risk, and how much you expect to gain.
# - __RISK MANAGEMENT__ : decide in advance how many dollars you’re prepared to risk on
# this trade. Divide that amount by your risk per share—the distance from your entry to
# your stop. __This will give you the number of shares you may trade__.
# - __CLEAR TRADING STRATEGIES__ : Last but not least, every single trade must be based on a specific system or strategy. “It looks good to me” isn’t a system!

# %% [markdown]
# <h3>39.  Triple Screen Trading System<h5>p.154</h5></h3>
#
# I’ve been using it for trading since 1985, and it stood the test of
# time. I continue to tweak it, adding or changing minor features, but its basic prin-
# ciple remains unchanged: __making trading decisions using a sequence of timeframes
# and indicators__.
#
# - The Triple Screen combines __trend-following indicators__ on _long-term charts_ with __counter-trend oscillators__ on the _intermediate charts_. It uses special entry techniques for buying or selling short as well as tight money management rules.
#
# - Trend-following indicators are profitable when markets are moving but lead to whipsaws in trading ranges. Oscillators are profitable in trading ranges, but give premature and dangerous signals when the markets begin to trend.

# %% [markdown]
# <h3>40. The Impulse System<h5> p.162</h5></h3>
#
# - Elder argue that he could describe any market move in any timeframe, using only two criteria: __inertia__ and __power__.
# - By combining them, he could find stocks and futures with both bullish inertia and bullish power and trade them long.
# > - metric for __inertia__ : slope of its fast EMA
# > - metric for __power__ : slope MACD-Histogram
#
# -  this wasn’t an automatic trading system—it was a censorship system! It didn’t tell me what to do—__it told me what not to do__.
#
# ![image.png](attachment:d2832902-2029-4f55-aa0d-38bb0eecfd79.png)
#
# ![image.png](attachment:2d933145-ae53-43a7-82f8-07a24a009bef.png)
#
# -  He develop my trading plans based on any number of ideas, signals, or indicators—and then __the Impulse system forces him to wait
# until it no longer prohibits an entry in the planned direction__.
# - In addition, the Impulse system helps him __to recognize when a trend starts weakening and suggests
# an exit__.

# %% [markdown]
# <h4>Entries</h4>
# Green and red bars of the Impulse system show when both inertia and power are
# pointing in the same direction. A fast EMA and MACD-Histogram may stay in gear with each other for only a few
# bars, but that’s when the market travels fast—the impulse is on!
#
#
# <h4>Exits</h4>

# %% [markdown]
# <h3>41.  Channel Trading System<h5>p.166</h5></h3>
